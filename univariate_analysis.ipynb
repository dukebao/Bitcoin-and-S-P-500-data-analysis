# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# we will first examine the S&P 500 dataset

# %%
snpdata = pd.read_csv('S&P 500 Historical Data 2018 to 2022.csv')
snpdf = snpdata.set_index(pd.DatetimeIndex(snpdata['Date']))
snpdf
# Out:
#                   Date     Price      Open      High       Low  Vol. Change %
# Date
# 2021-12-31  12/31/2021  4,766.18  4,775.21  4,786.83  4,765.75   NaN   -0.26%
# 2021-12-30  12/30/2021  4,778.73  4,794.23  4,808.93  4,775.33   NaN   -0.30%
# 2021-12-29  12/29/2021  4,793.06  4,788.64  4,804.06  4,778.08   NaN    0.14%
# 2021-12-28  12/28/2021  4,786.36  4,795.49  4,807.02  4,780.04   NaN   -0.10%
# 2021-12-27  12/27/2021  4,791.19  4,733.99  4,791.49  4,733.99   NaN    1.38%
# ...                ...       ...       ...       ...       ...   ...      ...
# 2018-01-08  01/08/2018  2,747.71  2,742.67  2,748.51  2,737.60   NaN    0.17%
# 2018-01-05  01/05/2018  2,743.15  2,731.33  2,743.45  2,727.92   NaN    0.70%
# 2018-01-04  01/04/2018  2,723.99  2,719.31  2,729.29  2,719.07   NaN    0.40%
# 2018-01-03  01/03/2018  2,713.06  2,697.85  2,714.37  2,697.77   NaN    0.64%
# 2018-01-02  01/02/2018  2,695.81  2,683.73  2,695.89  2,682.36   NaN    0.83%
#
# [1008 rows x 7 columns]

# %%
snpdata = pd.read_csv('S&P 500 Historical Data 2018 to 2022.csv')
snpdf = snpdata.set_index(pd.DatetimeIndex(snpdata['Date']))

snpdf['Price'] = snpdf['Price'].str.replace(',','').astype(float)
snpdf['Open'] = snpdf['Open'].str.replace(',','').astype(float)
snpdf['High'] = snpdf['High'].str.replace(',','').astype(float)
snpdf['Low'] = snpdf['Low'].str.replace(',','').astype(float)

# %% [markdown]
# I want to look at some basic statistic .... so lets convert all columns that i am interested into float

# %%
## Univariate Analysis
# convert the data to float 
# snpdf['Price'] = snpdf['Price'].str.replace(',', '').astype(float)

snpdf.describe()
# Out:
#              Price         Open         High          Low  Vol.
# count  1008.000000  1008.000000  1008.000000  1008.000000   0.0
# mean   3288.179692  3287.546617  3305.559940  3268.267143   NaN
# std     637.798788   636.783584   637.480842   637.369257   NaN
# min    2237.400000  2290.710000  2300.730000  2191.860000   NaN
# 25%    2798.342500  2798.775000  2809.505000  2782.335000   NaN
# 50%    3005.585000  3006.380000  3016.780000  2991.500000   NaN
# 75%    3728.290000  3731.695000  3757.140000  3713.910000   NaN
# max    4793.060000  4795.490000  4808.930000  4780.040000   NaN

# %% [markdown]
# Now lets Plot the data ....

# %%
# plot the data
plt.figure(figsize=(12, 6))
plt.plot(snpdf['Price'], color='blue', label='S&P 500')
plt.title('S&P 500 Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# Now , lets perform similar analysis with Bitcoin

# %%
bitcoindata = pd.read_csv('Bitcoin Historical Data - Investing.com 2018 to 2022.csv')
bitcoindf = bitcoindata.set_index(pd.DatetimeIndex(bitcoindata['Date']))
bitcoindf['Price'] = bitcoindf['Price'].str.replace(',','').astype(float)
bitcoindf['Open'] = bitcoindf['Open'].str.replace(',','').astype(float)
bitcoindf['High'] = bitcoindf['High'].str.replace(',','').astype(float)
bitcoindf['Low'] = bitcoindf['Low'].str.replace(',','').astype(float)
bitcoindf
# Out:
#                  Date    Price     Open     High      Low     Vol. Change %
# Date
# 2022-01-01  01-Jan-22  47738.0  46217.5  47917.6  46217.5   31.24K    3.29%
# 2021-12-31  31-Dec-21  46219.5  47123.3  48553.9  45693.6   58.18K   -1.92%
# 2021-12-30  30-Dec-21  47123.3  46470.7  47901.4  46003.0   60.96K    1.42%
# 2021-12-29  29-Dec-21  46461.7  47548.4  48121.7  46127.8   63.92K   -2.28%
# 2021-12-28  28-Dec-21  47545.2  50703.4  50703.8  47345.7   74.39K   -6.18%
# ...               ...      ...      ...      ...      ...      ...      ...
# 2018-01-05  05-Jan-18  16954.8  15180.1  17126.9  14832.4  141.96K   11.69%
# 2018-01-04  04-Jan-18  15180.1  15156.5  15408.7  14244.7  110.97K    0.15%
# 2018-01-03  03-Jan-18  15156.6  14754.1  15435.0  14579.7  106.54K    2.73%
# 2018-01-02  02-Jan-18  14754.1  13444.9  15306.1  12934.2  137.73K    9.74%
# 2018-01-01  01-Jan-18  13444.9  13850.5  13921.5  12877.7   78.43K   -2.93%
#
# [1462 rows x 7 columns]

# %%
# convert the data to float


bitcoindf.describe()
# Out:
#               Price          Open          High          Low
# count   1462.000000   1462.000000   1462.000000   1462.00000
# mean   18376.747196  18353.726813  18869.710739  17775.46409
# std    17765.305668  17749.198641  18255.468329  17172.32744
# min     3228.700000   3228.600000   3282.300000   3177.00000
# 25%     7082.000000   7081.975000   7285.300000   6854.67500
# 50%     9459.700000   9459.550000   9673.950000   9246.25000
# 75%    29257.275000  28930.475000  29545.025000  28159.62500
# max    67527.900000  67528.700000  68990.600000  66334.90000

# %%
# plot the data
plt.figure(figsize=(12, 6))
plt.plot(bitcoindf['Price'], color='red', label='Bitcoin')
plt.title('Bitcoin Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# Now, Lets plot them together

# %%
# plot the data
plt.figure(figsize=(12, 6))
plt.plot(snpdf['Price'], color='blue', label='S&P 500')
plt.plot(bitcoindf['Price'], color='red', label='Bitcoin')
plt.title('S&P 500 vs Bitcoin')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ACTUALLY... this is not how the stock markets works ...
#
# In order for us to have a fair comparism , the data needs to be NORMALIZEd

# %% [markdown]
# Now, Lets normalize the data so we can have some fair comparism

# %%
# normalize the data

snpdf['Price'] = (snpdf['Price'] - snpdf['Price'].min()) / (snpdf['Price'].max() - snpdf['Price'].min())
snpdf

# normalize the data
bitcoindf['Price'] = (bitcoindf['Price'] - bitcoindf['Price'].min()) / (bitcoindf['Price'].max() - bitcoindf['Price'].min())
bitcoindf

# plot the data
plt.figure(figsize=(12, 6))
plt.plot(snpdf['Price'], color='blue', label='S&P 500')
plt.plot(bitcoindf['Price'], color='red', label='Bitcoin')
plt.title('S&P 500 vs Bitcoin')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# Assuming we are using this past 4 year of data as our base line
# we will create the VaR ( Value at Risk ) statistic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from math import *

# %%
snpdata = pd.read_csv('S&P 500 Historical Data 2018 to 2022.csv')
snpdf = snpdata.set_index(pd.DatetimeIndex(snpdata['Date']))

# convert the data to float
snpdf['Price'] = snpdf['Price'].str.replace(',', '').astype(float)



# calcualte the confidence interval for S&P 500
SP_CI_mean = snpdf['Price'].mean()
SP_CI_std = snpdf['Price'].std()
SP_CI_n = snpdf['Price'].count()

SP_t_value = stats.t.ppf(1-0.05, SP_CI_n-1)
SP_CI_lower = SP_CI_mean - SP_t_value * SP_CI_std / sqrt(SP_CI_n)
SP_CI_upper = SP_CI_mean + SP_t_value * SP_CI_std / sqrt(SP_CI_n)
print("Note: 95% confidence interval")
print('S&P mean : ', SP_CI_mean)
print('S&P 500 Confidence Interval: ', SP_CI_lower, SP_CI_upper)
# normalize the data
print('S&P 500 normalized data')

bitcoindata = pd.read_csv('Bitcoin Historical Data - Investing.com 2018 to 2022.csv')
bitcoindf = bitcoindata.set_index(pd.DatetimeIndex(bitcoindata['Date']))

# convert the data to float
bitcoindf['Price'] = bitcoindf['Price'].str.replace(',', '').astype(float)

# calcualte the confidence interval for Bitcoin
BTC_CI_mean = bitcoindf['Price'].mean()
BTC_CI_std = bitcoindf['Price'].std()
BTC_CI_n = bitcoindf['Price'].count()

BTC_t_value = stats.t.ppf(1-0.05, BTC_CI_n-1)
BTC_CI_lower = BTC_CI_mean - BTC_t_value * BTC_CI_std / sqrt(BTC_CI_n)
BTC_CI_upper = BTC_CI_mean + BTC_t_value * BTC_CI_std / sqrt(BTC_CI_n)
print('bitcoin mean : ', BTC_CI_mean)
print('Bitcoin Confidence Interval: ', BTC_CI_lower, BTC_CI_upper)
# Out:
# Note: 95% confidence interval
# S&P mean :  3288.1796924603173
# S&P 500 Confidence Interval:  3255.1061743511104 3321.253210569524
# bitcoin mean :  18376.747195622433
# Bitcoin Confidence Interval:  17612.028480111527 19141.46591113334

# %% [markdown]
# What does this mean ? This means that based on the data for the past 4 years
#
# We are 95% confidence that the value of a unit of S&P500 will fall in between 3255 to 3321
#
# and we are 95% confidence that the value of a unit of Bitcoin will fall in between 17612 to 19141

# %% [markdown]
# Howver , This does not look quiet right ...
#
# The core issue is that Stock price is not normal distribution
#
# How do we fix it ?
#
# 1. Find a distribution that matches the shape of your data and use that distribution to calculate the confidence interval.
# 2. Perform a transformation on your data to make it fit a normal distribution, and then find the confidence interval for the transformed data.
#
# For this project , I will be transforming the data to make it fit a normal distribution

# %%
def map_x_with_data(x, data):
    print('x: ', x)
    print(data)
    return data.iloc[x]

# %%
snpdata = pd.read_csv('S&P 500 Historical Data 2018 to 2022.csv')
snpdf = snpdata.set_index(pd.DatetimeIndex(snpdata['Date']))
x = np.array([i for i in reversed(range(len(snpdf['Price'])))])
snpdf['Price'] = snpdf['Price'].str.replace(',','').astype(float)
snpdf['Open'] = snpdf['Open'].str.replace(',','').astype(float)
snpdf['High'] = snpdf['High'].str.replace(',','').astype(float)
snpdf['Low'] = snpdf['Low'].str.replace(',','').astype(float)
plt.figure(figsize=(12, 6))
plt.plot(x, snpdf['Price'], color='blue', label='S&P 500')
plt.title('S&P 500 Price')
plt.xlabel('Date')
plt.ylabel('Price')


# Draw a straight line of best fit for S&P 500
# plt.figure(figsize=(12, 6))
x = np.array([i for i in reversed(range(len(snpdf['Price'])))])
# # convert the data to float
y = np.array(snpdf['Price'])
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='green', label='S&P 500')


plt.legend()
plt.show()

# %% [markdown]
# The green line represents the line of best fit
#
# and the deviation of the actual price from that line should now follow normal distribution

# %%
# calculate the differce between the line and the data 
# for S&P 500

# print(snpdf['Price'])

# let y be the data
# let x be the index

calculated_y = m*x + b

# find out the actual value vs the calculated value
# for S&P 500
difference = y - calculated_y

# convernt array to numpy array 
difference = np.array(difference.tolist())

# caluclate the confidence interval for the difference
# for S&P 500
diff_CI_mean = difference.mean()
diff_CI_std = difference.std()
diff_CI_n = len(difference)
# diff_CI_z = 1.96
diff_t_value = stats.t.ppf(1-0.05, diff_CI_n-1)
diff_CI_lower = diff_CI_mean - diff_t_value * diff_CI_std / sqrt(diff_CI_n)
diff_CI_upper = diff_CI_mean + diff_t_value * diff_CI_std / sqrt(diff_CI_n)
print('S&P 500 Difference Confidence Interval: ', diff_CI_lower, diff_CI_upper)
# Out:
# S&P 500 Difference Confidence Interval:  -15.017852962637269 15.01785296263599

# %%
# Bitcoin
bitcoindata = pd.read_csv('Bitcoin Historical Data - Investing.com 2018 to 2022.csv')
bitcoindf = bitcoindata.set_index(pd.DatetimeIndex(bitcoindata['Date']))
x = np.array([i for i in reversed(range(len(bitcoindf['Price'])))])
bitcoindf['Price'] = bitcoindf['Price'].str.replace(',','').astype(float)
bitcoindf['Open'] = bitcoindf['Open'].str.replace(',','').astype(float)
bitcoindf['High'] = bitcoindf['High'].str.replace(',','').astype(float)
bitcoindf['Low'] = bitcoindf['Low'].str.replace(',','').astype(float)
plt.figure(figsize=(12, 6))
plt.plot(x, bitcoindf['Price'], color='blue', label='Bitcoin')
plt.title('Bitcoin Price')
plt.xlabel('Date')
plt.ylabel('Price')

# Draw a straight line of best fit for bitcoin
# plt.figure(figsize=(12, 6))
x = np.array([i for i in reversed(range(len(bitcoindf['Price'])))])
# # convert the data to float
y = np.array(bitcoindf['Price'])
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='green', label='Bitcoin')

plt.legend()
plt.show()

# %%
# calculate the differce between the line and the data 
# for Bitcoin

# print(bitcoindf['Price'])

# let y be the data
# let x be the index

calculated_y = m*x + b

# find out the actual value vs the calculated value

# for Bitcoin
difference = y - calculated_y

# convernt array to numpy array
difference = np.array(difference.tolist())

# caluclate the confidence interval for the difference
# for Bitcoin
diff_CI_mean = difference.mean()
diff_CI_std = difference.std()
diff_CI_n = len(difference)
# diff_CI_z = 1.96
diff_t_value = stats.t.ppf(1-0.05, diff_CI_n-1)
diff_CI_lower = diff_CI_mean - diff_t_value * diff_CI_std / sqrt(diff_CI_n)
diff_CI_upper = diff_CI_mean + diff_t_value * diff_CI_std / sqrt(diff_CI_n)
print('Bitcoin Difference Confidence Interval: ', diff_CI_lower, diff_CI_upper)
# Out:
# Bitcoin Difference Confidence Interval:  -484.3844321022497 484.38443210223505
